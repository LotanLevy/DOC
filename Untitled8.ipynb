# %% [markdown]
# <a href="https://colab.research.google.com/github/LotanLevy/DOC/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
from PIL import Image
import re
IMAGENET_PATH = "/content/drive/My Drive/Colab Notebooks/affordances/datasets/ImageNet/imagenet_val"
LABELS_FILE_PATH = "/content/drive/My Drive/Colab Notebooks/affordances/datasets/ImageNet/imagenet_labels.txt"
OUTPUT_DIR = "/content/drive/My Drive/Colab Notebooks/affordances/datasets/imagenet_val_splitted"


def get_num(image_name):
  pattern = "ILSVRC2012_val_((\d)*).JPEG"
  print(image_name)
  m = re.match(pattern, image_name)
  return m.group(1)

images_names = sorted(os.listdir(IMAGENET_PATH))

with open(LABELS_FILE_PATH, 'r') as f:
  labels = f.read().splitlines()

if not os.path.exists(OUTPUT_DIR):
  os.makedirs(OUTPUT_DIR)



image_to_label = list(zip(images_names, labels))
with open(os.path.join(OUTPUT_DIR, "paths2labels.txt"), 'w') as f:
    for item in images_names:
      # try:
      label_idx = int(get_num(item))
      f.write("{},{}\n".format(item, labels[label_idx]))
      # except:
      #   image_path = os.path.join(IMAGENET_PATH, item)
      #   os.remove(image_path)
      #   print("image {} removed".format(image_path))
      #   continue
# for pair in image_to_label:
#   if (pair[0].contains('33602')):
#     print(pair)
#   new_dir_path = os.path.join(OUTPUT_DIR, pair[1])
#   if not os.path.exists(new_dir_path):
#     os.makedirs(new_dir_path) 
#   image_path = os.path.join(IMAGENET_PATH, pair[0])

#   if not os.path.exists(image_path):
#     im = Image.open(image_path, 'r')
#     im.save(os.path.join(new_dir_path, pair[0]))
# Out:
# Streaming output truncated to the last 5000 lines.
# ILSVRC2012_val_00029438.JPEG
# ILSVRC2012_val_00029439.JPEG
# ILSVRC2012_val_00029440.JPEG
# ILSVRC2012_val_00029441.JPEG
# ILSVRC2012_val_00029442.JPEG
# ILSVRC2012_val_00029443.JPEG
# ILSVRC2012_val_00029444.JPEG
# ILSVRC2012_val_00029445.JPEG
# ILSVRC2012_val_00029446.JPEG
# ILSVRC2012_val_00029447.JPEG
# ILSVRC2012_val_00029448.JPEG
# ILSVRC2012_val_00029449.JPEG
# ILSVRC2012_val_00029450.JPEG
# ILSVRC2012_val_00029451.JPEG
# ILSVRC2012_val_00029452.JPEG
# ILSVRC2012_val_00029453.JPEG
# ILSVRC2012_val_00029454.JPEG
# ILSVRC2012_val_00029455.JPEG
# ILSVRC2012_val_00029456.JPEG
# ILSVRC2012_val_00029457.JPEG
# ILSVRC2012_val_00029458.JPEG
# ILSVRC2012_val_00029459.JPEG
# ILSVRC2012_val_00029460.JPEG
# ILSVRC2012_val_00029461.JPEG
# ILSVRC2012_val_00029462.JPEG
# ILSVRC2012_val_00029463.JPEG
# ILSVRC2012_val_00029464.JPEG
# ILSVRC2012_val_00029465.JPEG
# ILSVRC2012_val_00029466.JPEG
# ILSVRC2012_val_00029467.JPEG
# ...
